# %% [markdown]
# # Interim -> final processed data

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../../data/interim/s9_working.csv')

# %%
# final processing, dropping partial features (prescout irrelevant), features with all nans, or perfectly correlated features (trying both)

# features with all nans or no variance, and partial
to_drop = ['rank', 'affinity', 'type'] +  ['ds2_def_type', 'ds2_invul', 'as1_heals_one_or_many', 'as2_def_type', 'as2_invul', 'as2_heals_one_or_many']\
+ [c for c in df.columns if c.endswith('_PARTIAL')]

full_csv = df.drop(columns=to_drop)

full_csv = full_csv.replace(to_replace='?', value=np.nan)

# %%
full_csv.to_csv('../../data/processed/s9_final.csv', index=False)
