# %%
import pandas as pd

# %%
path_to_csv = '../s9/data/s9.csv'

df = pd.read_csv(path_to_csv)

# %%
# <h1>MAINSTAYS<h1>

#%%%%% Strikers %%%%%#
# - hoshino
# - tshiroko
# - haruka
# - iori
# - reisa
# - marina
# - saori
# - eimi
# - tsurugi
# - shun
# - nyharuna
# - nymutsuki
# - shanako

#%%%%% Specials %%%%%#
# - sshiroko
# - hibiki
# - nagisa
# - sayane
# - saki
# - sayane
# - sayane
# - hibiki
# - minori
# - nyserika

# %%
### ADD ATK DATA
new_row = ['indoor', 'atk',
           
            # DEFENSE
            'reisa', # d1
            'tshiroko', # d2
            'shun', # d3
            'haruka', # d4

            'saki', # ds1
            'sshiroko', # always shiroko ds2

            # ATTACK
            'hoshino', # a1
            'iori', # a2
            'Tshiroko', # a3
            'marina', # a4

            'sayane', # as1
            'sshiroko', # always shiroko as2

            0, # did you win?
            61 # rank (after atking)
            ]

pd.DataFrame([new_row]).to_csv(path_to_csv, mode="a", index=False, header=False)

# %%
### ADD DEF DATA
new_row = ['indoor','def',
           
            # DEFENSE
            'hoshino', # d1
            'shun', # d2
            'tshiroko', # d3
            'marina', # d4

            'sayane', # ds1
            'sshiroko', # always shiroko ds2

            # ATTACK
            'Tshiroko', # a1
            'shun', # a2
            'iori', # a3
            'marina', # a4

            'nagisa', # as1
            'sshiroko', # always shiroko as2

            0, # did you win?
            ]

pd.DataFrame([new_row]).to_csv(path_to_csv, mode="a", index=False, header=False)
