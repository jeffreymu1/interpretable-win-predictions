# %%
import pandas as pd

# %%
path_to_csv = '../s9/s9.csv'

df = pd.read_csv(path_to_csv)

# %%
# <h1>MAINSTAYS<h1>

#%%%%% Strikers %%%%%#
# - hoshino
# - tshiroko
# - haruka
# - iori
# - reisa
# - marina
# - saori
# - eimi
# - tsurugi
# - shun
# - nyharuna
# - nymutsuki
# - shanako

#%%%%% Specials %%%%%#
# - sshiroko
# - hibiki
# - nagisa
# - sayane
# - saki
# - sayane
# - sayane
# - hibiki
# - minori
# - nyserika

# %%
### ADD ATK DATA
new_row = ['indoor', 'atk',
           
            # DEFENSE
            'tshiroko', # d1
            'marina', # d2
            'shun', # d3
            'hoshino', # d4

            'nagisa', # ds1
            'sshiroko', # always shiroko ds2

            # ATTACK
            'hoshino', # a1
            'iori', # a2
            'tshiroko', # a3
            'marina', # a4

            'sayane', # as1
            'sshiroko', # always shiroko as2

            1, # did you win?
            72 # rank (after atking)
            ]

pd.DataFrame([new_row]).to_csv(path_to_csv, mode="a", index=False, header=False)

# %%
### ADD DEF DATA
new_row = ['indoor','def',
           
            # DEFENSE
            'marina', # d1
            'shun', # d2
            'tshiroko', # d3
            'hoshino', # d4

            'sayane', # ds1
            'sshiroko', # always shiroko ds2

            # ATTACK
            'marina', # a1
            'shun', # a2
            'hoshino', # a3
            'tshiroko', # a4

            'nagisa', # as1
            'sshiroko', # always shiroko as2

            0, # did you win?
            ]

pd.DataFrame([new_row]).to_csv(path_to_csv, mode="a", index=False, header=False)
