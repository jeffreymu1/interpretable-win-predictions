# %%
import pandas as pd

# %%
df = pd.read_csv('../s9/s9.csv')

uniques = set(df['d1'].unique().tolist() + df['d2'].unique().tolist() + df['d3'].unique().tolist() + df['d4'].unique().tolist()\
+ df['a1'].unique().tolist() + df['a2'].unique().tolist() + df['a3'].unique().tolist() + df['a4'].unique().tolist())

# %%
uniques = set(df['as1'].unique().tolist()+df['ds1'].unique().tolist())

# %%
# table of all common strikers and attributes, also ex skill stuffs, deals dmg vs buff? heals vs shield, deals dmg ex vs basic?, map features?
# NOTES: scaled to ue60 standard, max everything

striker_attributes = pd.DataFrame([
    # TSHIROKO
    {'char': 'tshiroko', 'atk_type': 'blue', 'def_type': 'blue', 'role': 'dealer', 'weapon': 'ar', 'position': 'middle',
     'affinity_urban': 'D', 'affinity_outdoor': 'SS', 'affinity_indoor':'A', 'unit_type': 'striker', 'alt_count': 0,

     'invul': 'yes', 'deals_dmg': 'yes', 'heals': 'no', 'heals_team_or_self': '?', 
     'ex_cost': 3, 'ex_length': 3.33, 'generates_cost': 'no', 'taunts': 'no',
     
     'max_hp': 69289, 'atk': 6276, 'def': 108, 'dmg_reduction': 0.0609, 'healing': 5932, 'accuracy': 709,
     'evasion': 1239, 'crit': 733, 'crit_res': 100, 'crit_dmg': 2.46, 'crit_dmg_res': 0.5, 'stability': 1380,
     'min_dmg': 0.7798, 'stability_rate': 0.2, 'n_range': 650, 's_range': 800, 'cc_power': 100, 'cc_res': 100,
     'recov_boost': 0.35, 'cost_recovery': 700, 'atk_spd': 1.0, 'mov_spd': 200, 'block_rate_bonus': 0.0, 
     'def_piercing': 0, 'mag_count': 15, 'na_cost': 3,
     
     'equip_slot1': 'hat', 'equip_slot2': 'badge', 'equip_slot3': 'wristwatch'

     },

    # HOSHINO
    {'char': 'hoshino', 'atk_type': 'yellow', 'def_type': 'yellow', 'role': 'tank', 'weapon': 'sg', 'position': 'front',
     'affinity_urban': 'D', 'affinity_outdoor': 'SS', 'affinity_indoor':'B', 'unit_type': 'striker', 'alt_count': 2,

     'invul': 'no', 'deals_dmg': 'yes', 'heals': 'yes', 'heals_team_or_self': 'self', 
     'ex_cost': 4, 'ex_length': 7.63, 'generates_cost': 'no', 'taunts': 'no',
     
     'max_hp': 111386, 'atk': 4757, 'def': 2792, 'dmg_reduction': 0.6262, 'healing': 7077, 'accuracy': 615, 
     'evasion': 246, 'crit': 505, 'crit_res': 520, 'crit_dmg': 2.0, 'crit_dmg_res': 1.0, 'stability': 1948, 
     'min_dmg': 0.8608, 'stability_rate': 0.2, 'n_range': 350, 's_range': 800, 'cc_power': 100, 'cc_res': 100, 
     'recov_boost': 0.0, 'cost_recovery': 700, 'atk_spd': 1.0, 'mov_spd': 200, 'block_rate_bonus': 0.0, 
     'def_piercing': 0, 'mag_count': 8, 'na_cost': 1,
     
     'equip_slot1': 'shoes', 'equip_slot2': 'bag', 'equip_slot3': 'amulet'
     
     },

    # IORI
    {'char': 'iori', 'atk_type': 'yellow', 'def_type': 'yellow', 'role': 'dealer', 'weapon': 'sr', 'position': 'back',
     'affinity_urban': 'C', 'affinity_outdoor': 'C', 'affinity_indoor':'SS', 'unit_type': 'striker', 'alt_count': 1,
     
     'invul': 'no', 'deals_dmg': 'yes', 'heals': 'no', 'heals_team_or_self': '?', 
     'ex_cost': 3, 'ex_length': 7.33, 'generates_cost': 'no', 'taunts': 'no',
     
     'max_hp': 52713, 'atk': 8067, 'def': 113, 'dmg_reduction': 0.0635, 'healing': 5497, 'accuracy': 1491,
     'evasion': 194, 'crit': 824, 'crit_res': 100, 'crit_dmg': 2.46, 'crit_dmg_res': 0.5, 'stability': 2056,
     'min_dmg': 0.8728, 'stability_rate': 0.2, 'n_range': 650, 's_range': 800, 'cc_power': 100, 'cc_res': 136,
     'recov_boost': 0.0, 'cost_recovery': 700, 'atk_spd': 1.0, 'mov_spd': 200, 'block_rate_bonus': 0.0,
     'def_piercing': 0, 'mag_count': 5, 'na_cost': 1,
     
     'equip_slot1': 'hat', 'equip_slot2': 'hairpin', 'equip_slot3': 'wristwatch'
     
     },

    # AZUSA
    {'char': 'azusa', 'atk_type': 'red', 'def_type': 'yellow', 'role': 'dealer', 'weapon': 'ar', 'position': 'middle',
     'affinity_urban': 'B', 'affinity_outdoor': 'D', 'affinity_indoor':'SS', 'unit_type': 'striker', 'alt_count': 1,

     'invul': 'no', 'deals_dmg': 'yes', 'heals': 'no', 'heals_team_or_self': '?', 
     'ex_cost': 5, 'ex_length': 3.63, 'generates_cost': 'no', 'taunts': 'no',
     
     'max_hp': 53680, 'atk': 5130, 'def': 108, 'dmg_reduction': 0.0609, 'healing': 5714, 'accuracy': 926,
     'evasion': 792, 'crit': 1875, 'crit_res': 100, 'crit_dmg': 2.26, 'crit_dmg_res': 0.5, 'stability': 1384,
     'min_dmg': 0.7805, 'stability_rate': 0.2, 'n_range': 650, 's_range': 800, 'cc_power': 100, 'cc_res': 136,
     'recov_boost': 0.0, 'cost_recovery': 700, 'atk_spd': 1.0, 'mov_spd': 200, 'block_rate_bonus': 0.0,
     'def_piercing': 0, 'mag_count': 15, 'na_cost': 1,
     
     'equip_slot1': 'gloves', 'equip_slot2': 'hairpin', 'equip_slot3': 'wristwatch'
     
     },

    # SHUN
    {'char': 'shun', 'atk_type': 'red', 'def_type': 'red', 'role': 'dealer', 'weapon': 'sr', 'position': 'back',
     'affinity_urban': 'SS', 'affinity_outdoor': 'B', 'affinity_indoor':'D', 'unit_type': 'striker', 'alt_count': 1,

     'invul': 'no', 'deals_dmg': 'yes', 'heals': 'no', 'heals_team_or_self': '?', 
     'ex_cost': 3, 'ex_length': 2.47, 'generates_cost': 'yes', 'taunts': 'no',
     
     'max_hp': 46867, 'atk': 10930, 'def': 108, 'dmg_reduction': 0.0609, 'healing': 5715, 'accuracy': 1128,
     'evasion': 201, 'crit': 1382, 'crit_res': 100, 'crit_dmg': 2.26, 'crit_dmg_res': 0.5, 'stability': 1980,
     'min_dmg': 0.8644, 'stability_rate': 0.2, 'n_range': 750, 's_range': 800, 'cc_power': 100, 'cc_res': 136,
     'recov_boost': 0.0, 'cost_recovery': 700, 'atk_spd': 1.0, 'mov_spd': 200, 'block_rate_bonus': 0.0,
     'def_piercing': 0, 'mag_count': 20, 'na_cost': 1,
     
     'equip_slot1': 'gloves', 'equip_slot2': 'hairpin', 'equip_slot3': 'wristwatch'
     
     },

    # MARINA
    {'char': 'marina', 'atk_type': 'yellow', 'def_type': 'red', 'role': 'tank', 'weapon': 'smg', 'position': 'front',
     'affinity_urban': 'D', 'affinity_outdoor': 'B', 'affinity_indoor':'SS', 'unit_type': 'striker', 'alt_count': 1,

     'invul': 'yes', 'deals_dmg': 'yes', 'heals': 'no', 'heals_team_or_self': '?', 
     'ex_cost': 3, 'ex_length': 8.83, 'generates_cost': 'no', 'taunts': 'no',
     
     'max_hp': 134170, 'atk': 3913, 'def': 148, 'dmg_reduction': 0.0816, 'healing': 6197, 'accuracy': 109,
     'evasion': 2219, 'crit': 518, 'crit_res': 520, 'crit_dmg': 2.0, 'crit_dmg_res': 0.8, 'stability': 1264,
     'min_dmg': 0.7583, 'stability_rate': 0.2, 'n_range': 350, 's_range': 800, 'cc_power': 100, 'cc_res': 100,
     'recov_boost': 0.35, 'cost_recovery': 700, 'atk_spd': 1.0, 'mov_spd': 200, 'block_rate_bonus': 0.0,
     'def_piercing': 0, 'mag_count': 20, 'na_cost': 4,
     
     'equip_slot1': 'shoes', 'equip_slot2': 'badge', 'equip_slot3': 'amulet'
     
     },

    # SHANAKO
    {'char': 'shanako', 'atk_type': 'purple', 'def_type': 'yellow', 'role': 'dealer', 'weapon': 'ar', 'position': 'middle',
     'affinity_urban': 'SS', 'affinity_outdoor': 'A', 'affinity_indoor':'D', 'unit_type': 'striker', 'alt_count': 2,

     'invul': 'no', 'deals_dmg': 'yes', 'heals': 'no', 'heals_team_or_self': '?', 
     'ex_cost': 2, 'ex_length': 3.83, 'generates_cost': 'no', 'taunts': 'no',
     
     'max_hp': 53852, 'atk': 9363, 'def': 109, 'dmg_reduction': 0.0614, 'healing': 6158, 'accuracy': 701,
     'evasion': 797, 'crit': 830, 'crit_res': 100, 'crit_dmg': 3.1292, 'crit_dmg_res': 0.5, 'stability': 1396,
     'min_dmg': 0.7826, 'stability_rate': 0.2, 'n_range': 650, 's_range': 800, 'cc_power': 100, 'cc_res': 136,
     'recov_boost': 0.0, 'cost_recovery': 700, 'atk_spd': 1.0, 'mov_spd': 200, 'block_rate_bonus': 0.0,
     'def_piercing': 0, 'mag_count': 15, 'na_cost': 3,
     
     'equip_slot1': 'hat', 'equip_slot2': 'hairpin', 'equip_slot3': 'wristwatch'
     
     },

    # NYMUTSUKI
    {'char': 'nymutsuki', 'atk_type': 'blue', 'def_type': 'yellow', 'role': 'dealer', 'weapon': 'mg', 'position': 'back',
     'affinity_urban': 'D', 'affinity_outdoor': 'SS', 'affinity_indoor':'B', 'unit_type': 'striker', 'alt_count': 1,

     'invul': 'no', 'deals_dmg': 'yes', 'heals': 'no', 'heals_team_or_self': '?', 
     'ex_cost': 2, 'ex_length': 4.67, 'generates_cost': 'no', 'taunts': 'no',
     
     
     'max_hp': 62027, 'atk': 11562, 'def': 418, 'dmg_reduction': 0.2005, 'healing': 5939, 'accuracy': 324,
     'evasion': 640, 'crit': 1189, 'crit_res': 100, 'crit_dmg': 2.26, 'crit_dmg_res': 0.5, 'stability': 1328,
     'min_dmg': 0.7704, 'stability_rate': 0.2, 'n_range': 750, 's_range': 800, 'cc_power': 100, 'cc_res': 100,
     'recov_boost': 0.35, 'cost_recovery': 700, 'atk_spd': 1.0, 'mov_spd': 200, 'block_rate_bonus': 0.0,
     'def_piercing': 684, 'mag_count': 25, 'na_cost': 5,
     
     'equip_slot1': 'gloves', 'equip_slot2': 'badge', 'equip_slot3': 'wristwatch'
     
     },

    # nyharuna
    {'char': 'nyharuna', 'atk_type': 'red', 'def_type': 'red', 'role': 'dealer', 'weapon': 'sr', 'position': 'back',
     'affinity_urban': 'D', 'affinity_outdoor': 'SS', 'affinity_indoor':'B', 'unit_type': 'striker', 'alt_count': 2,

     'invul': 'no', 'deals_dmg': 'yes', 'heals': 'no', 'heals_team_or_self': '?', 
     'ex_cost': 5, 'ex_length': 4.10, 'generates_cost': 'no', 'taunts': 'no',
     
     'max_hp': 47527, 'atk': 10880, 'def': 104, 'dmg_reduction': 0.0587, 'healing': 6430, 'accuracy': 1161,
     'evasion': 190, 'crit': 1339, 'crit_res': 100, 'crit_dmg': 2.26, 'crit_dmg_res': 0.5, 'stability': 1908,
     'min_dmg': 0.8561, 'stability_rate': 0.2, 'n_range': 750, 's_range': 800, 'cc_power': 100, 'cc_res': 136,
     'recov_boost': 0.0, 'cost_recovery': 700, 'atk_spd': 1.0, 'mov_spd': 200, 'block_rate_bonus': 0.0,
     'def_piercing': 0, 'mag_count': 5, 'na_cost': 1,
     
     'equip_slot1': 'gloves', 'equip_slot2': 'hairpin', 'equip_slot3': 'wristwatch'
     
     },

    # reisa
    {'char': 'reisa', 'atk_type': 'yellow', 'def_type': 'yellow', 'role': 'tank', 'weapon': 'sg', 'position': 'front',
     'affinity_urban': 'D', 'affinity_outdoor': 'B', 'affinity_indoor':'SS', 'unit_type': 'striker', 'alt_count': 1,

     'invul': 'no', 'deals_dmg': 'yes', 'heals': 'yes', 'heals_team_or_self': 'self', 
     'ex_cost': 3, 'ex_length': 4.93, 'generates_cost': 'no', 'taunts': 'yes',
     
     'max_hp': 122892, 'atk': 5025, 'def': 2597, 'dmg_reduction': 0.6091, 'healing': 8080, 'accuracy': 655,
     'evasion': 217, 'crit': 518, 'crit_res': 520, 'crit_dmg': 2.0, 'crit_dmg_res': 0.8, 'stability': 1812,
     'min_dmg': 0.8444, 'stability_rate': 0.2, 'n_range': 350, 's_range': 800, 'cc_power': 100, 'cc_res': 100,
     'recov_boost': 0.0, 'cost_recovery': 700, 'atk_spd': 1.0, 'mov_spd': 200, 'block_rate_bonus': 0.0,
     'def_piercing': 0, 'mag_count': 8, 'na_cost': 2,
     
     'equip_slot1': 'shoes', 'equip_slot2': 'bag', 'equip_slot3': 'amulet'
     
     },

    # haruka
    {'char': 'haruka', 'atk_type': 'red', 'def_type': 'red', 'role': 'tank', 'weapon': 'sg', 'position': 'front',
     'affinity_urban': 'B', 'affinity_outdoor': 'B', 'affinity_indoor':'A', 'unit_type': 'striker', 'alt_count': 1,

     'invul': 'no', 'deals_dmg': 'yes', 'heals': 'no', 'heals_team_or_self': '?', 
     'ex_cost': 4, 'ex_length': 5.67, 'generates_cost': 'no', 'taunts': 'no',
     
     'max_hp': 150581, 'atk': 3216, 'def': 2700, 'dmg_reduction': 0.6183, 'healing': 5596, 'accuracy': 593,
     'evasion': 237, 'crit': 497, 'crit_res': 520, 'crit_dmg': 2.0, 'crit_dmg_res': 0.8, 'stability': 2020,
     'min_dmg': 0.8689, 'stability_rate': 0.2, 'n_range': 350, 's_range': 800, 'cc_power': 100, 'cc_res': 100,
     'recov_boost': 0.0, 'cost_recovery': 700, 'atk_spd': 1.0, 'mov_spd': 200, 'block_rate_bonus': 0.0,
     'def_piercing': 0, 'mag_count': 8, 'na_cost': 1,
     
     'equip_slot1': 'shoes', 'equip_slot2': 'bag', 'equip_slot3': 'amulet'
     
     },

    # sumire
    {'char': 'sumire', 'atk_type': 'yellow', 'def_type': 'blue', 'role': 'tank', 'weapon': 'sg', 'position': 'front',
     'affinity_urban': 'B', 'affinity_outdoor': 'D', 'affinity_indoor':'SS', 'unit_type': 'striker', 'alt_count': 1,

     'invul': 'no', 'deals_dmg': 'yes', 'heals': 'no', 'heals_team_or_self': '?', 
     'ex_cost': 3, 'ex_length': 3.80, 'generates_cost': 'no', 'taunts': 'no',
     
     'max_hp': 89359, 'atk': 6498, 'def': 2409, 'dmg_reduction': 0.5911, 'healing': 5611, 'accuracy': 594,
     'evasion': 198, 'crit': 498, 'crit_res': 520, 'crit_dmg': 2.2, 'crit_dmg_res': 0.8, 'stability': 2016,
     'min_dmg': 0.8684, 'stability_rate': 0.2, 'n_range': 450, 's_range': 800, 'cc_power': 100, 'cc_res': 100,
     'recov_boost': 0.0, 'cost_recovery': 700, 'atk_spd': 1.0, 'mov_spd': 200, 'block_rate_bonus': 0.0,
     'def_piercing': 0, 'mag_count': 8, 'na_cost': 1,
     
     'equip_slot1': 'hat', 'equip_slot2': 'bag', 'equip_slot3': 'amulet'
     
     },

    # yuuka
    {'char': 'yuuka', 'atk_type': 'red', 'def_type': 'yellow', 'role': 'tank', 'weapon': 'smg', 'position': 'front',
     'affinity_urban': 'A', 'affinity_outdoor': 'B', 'affinity_indoor':'A', 'unit_type': 'striker', 'alt_count': 2,

     'invul': 'no', 'deals_dmg': 'no', 'heals': 'yes', 'heals_team_or_self': 'self', 
     'ex_cost': 3, 'ex_length': 2.33, 'generates_cost': 'no', 'taunts': 'no',
     
     'max_hp': 135192, 'atk': 2812, 'def': 841, 'dmg_reduction': 0.3354, 'healing': 6901, 'accuracy': 100,
     'evasion': 1890, 'crit': 500, 'crit_res': 520, 'crit_dmg': 2.0, 'crit_dmg_res': 0.8, 'stability': 1396,
     'min_dmg': 0.7826, 'stability_rate': 0.2, 'n_range': 350, 's_range': 800, 'cc_power': 100, 'cc_res': 100,
     'recov_boost': 0.35, 'cost_recovery': 700, 'atk_spd': 1.0, 'mov_spd': 200, 'block_rate_bonus': 0.19,
     'def_piercing': 0, 'mag_count': 27, 'na_cost': 3,
     
     'equip_slot1': 'shoes', 'equip_slot2': 'badge', 'equip_slot3': 'amulet'
     
     },

    # miyako
    {'char': 'miyako', 'atk_type': 'yellow', 'def_type': 'yellow', 'role': 'tank', 'weapon': 'smg', 'position': 'front',
     'affinity_urban': 'SS', 'affinity_outdoor': 'D', 'affinity_indoor':'B', 'unit_type': 'striker', 'alt_count': 1,

     'invul': 'no', 'deals_dmg': 'yes', 'heals': 'no', 'heals_team_or_self': '?', 
     'ex_cost': 3, 'ex_length': 1.37, 'generates_cost': 'no', 'taunts': 'no',
     
     'max_hp': 164532, 'atk': 3408, 'def': 530, 'dmg_reduction': 0.2413, 'healing': 6162, 'accuracy': 108,
     'evasion': 1762, 'crit': 517, 'crit_res': 520, 'crit_dmg': 2.0, 'crit_dmg_res': 0.8, 'stability': 1272,
     'min_dmg': 0.7599, 'stability_rate': 0.2, 'n_range': 350, 's_range': 800, 'cc_power': 100, 'cc_res': 100,
     'recov_boost': 0.35, 'cost_recovery': 700, 'atk_spd': 1.0, 'mov_spd': 200, 'block_rate_bonus': 0.0,
     'def_piercing': 0, 'mag_count': 40, 'na_cost': 5,
     
     'equip_slot1': 'shoes', 'equip_slot2': 'badge', 'equip_slot3': 'amulet'
     
     },

    # mika
    {'char': 'mika', 'atk_type': 'yellow', 'def_type': 'red', 'role': 'dealer', 'weapon': 'smg', 'position': 'front',
     'affinity_urban': 'D', 'affinity_outdoor': 'A', 'affinity_indoor':'SS', 'unit_type': 'striker', 'alt_count': 0,

     'invul': 'no', 'deals_dmg': 'yes', 'heals': 'no', 'heals_team_or_self': '?', 
     'ex_cost': 6, 'ex_length': 5.90, 'generates_cost': 'no', 'taunts': 'no',
     
     'max_hp': 94020, 'atk': 7995, 'def': 121, 'dmg_reduction': 0.0677, 'healing': 5749, 'accuracy': 111,
     'evasion': 1867, 'crit': 505, 'crit_res': 100, 'crit_dmg': 2.46, 'crit_dmg_res': 0.5, 'stability': 1376,
     'min_dmg': 0.7791, 'stability_rate': 0.2, 'n_range': 450, 's_range': 800, 'cc_power': 100, 'cc_res': 100,
     'recov_boost': 0.35, 'cost_recovery': 700, 'atk_spd': 1.0, 'mov_spd': 200, 'block_rate_bonus': 0.0,
     'def_piercing': 0, 'mag_count': 25, 'na_cost': 5,
     
     'equip_slot1': 'hat', 'equip_slot2': 'badge', 'equip_slot3': 'wristwatch'
     
     },

    # tsurugi
    {'char': 'tsurugi', 'atk_type': 'yellow', 'def_type': 'yellow', 'role': 'dealer', 'weapon': 'sg', 'position': 'front',
     'affinity_urban': 'D', 'affinity_outdoor': 'B', 'affinity_indoor':'SS', 'unit_type': 'striker', 'alt_count': 1,

     'invul': 'no', 'deals_dmg': 'no', 'heals': 'yes', 'heals_team_or_self': 'self', 
     'ex_cost': 3, 'ex_length': 3.00, 'generates_cost': 'no', 'taunts': 'no',
     
     'max_hp': 71187, 'atk': 10424, 'def': 2462, 'dmg_reduction': 0.5963, 'healing': 6524, 'accuracy': 862,
     'evasion': 175, 'crit': 1043, 'crit_res': 520, 'crit_dmg': 2.0, 'crit_dmg_res': 0.8, 'stability': 2052,
     'min_dmg': 0.8723, 'stability_rate': 0.2, 'n_range': 450, 's_range': 800, 'cc_power': 100, 'cc_res': 100,
     'recov_boost': 0.0, 'cost_recovery': 700, 'atk_spd': 1.15, 'mov_spd': 253, 'block_rate_bonus': 0.0,
     'def_piercing': 0, 'mag_count': 8, 'na_cost': 2,
     
     'equip_slot1': 'gloves', 'equip_slot2': 'bag', 'equip_slot3': 'amulet'
     
     },

    # tsubaki
    {'char': 'tsubaki', 'atk_type': 'yellow', 'def_type': 'blue', 'role': 'tank', 'weapon': 'smg', 'position': 'front',
     'affinity_urban': 'A', 'affinity_outdoor': 'A', 'affinity_indoor':'B', 'unit_type': 'striker', 'alt_count': 1,

     'invul': 'no', 'deals_dmg': 'no', 'heals': 'no', 'heals_team_or_self': '?', 
     'ex_cost': 4, 'ex_length': 2.90, 'generates_cost': 'no', 'taunts': 'yes',
     
     'max_hp': 106589, 'atk': 3971, 'def': 2364, 'dmg_reduction': 0.5865, 'healing': 6420, 'accuracy': 98,
     'evasion': 1416, 'crit': 496, 'crit_res': 520, 'crit_dmg': 2.0, 'crit_dmg_res': 0.8, 'stability': 1420,
     'min_dmg': 0.7868, 'stability_rate': 0.2, 'n_range': 350, 's_range': 800, 'cc_power': 100, 'cc_res': 100,
     'recov_boost': 0.0, 'cost_recovery': 700, 'atk_spd': 1.266, 'mov_spd': 200, 'block_rate_bonus': 0.0,
     'def_piercing': 0, 'mag_count': 9, 'na_cost': 3,
     
     'equip_slot1': 'shoes', 'equip_slot2': 'bag', 'equip_slot3': 'amulet'
     
     },

    # junko
    {'char': 'junko', 'atk_type': 'yellow', 'def_type': 'red', 'role': 'dealer', 'weapon': 'ar', 'position': 'middle',
     'affinity_urban': 'B', 'affinity_outdoor': 'A', 'affinity_indoor':'A', 'unit_type': 'striker', 'alt_count': 1,

     'invul': 'yes', 'deals_dmg': 'yes', 'heals': 'no', 'heals_team_or_self': '?', 
     'ex_cost': 5, 'ex_length': 3.33, 'generates_cost': 'no', 'taunts': 'no',
     
     'max_hp': 53964, 'atk': 8538, 'def': 110, 'dmg_reduction': 0.0619, 'healing': 5624, 'accuracy': 695,
     'evasion': 1390, 'crit': 828, 'crit_res': 100, 'crit_dmg': 2.46, 'crit_dmg_res': 0.5, 'stability': 1408,
     'min_dmg': 0.7847, 'stability_rate': 0.2, 'n_range': 650, 's_range': 800, 'cc_power': 100, 'cc_res': 136,
     'recov_boost': 0.0, 'cost_recovery': 700, 'atk_spd': 1.0, 'mov_spd': 200, 'block_rate_bonus': 0.0,
     'def_piercing': 0, 'mag_count': 15, 'na_cost': 3,
     
     'equip_slot1': 'hat', 'equip_slot2': 'hairpin', 'equip_slot3': 'wristwatch'
     
     },

    # eimi
    {'char': 'eimi', 'atk_type': 'red', 'def_type': 'red', 'role': 'tank', 'weapon': 'sg', 'position': 'front',
     'affinity_urban': 'SS', 'affinity_outdoor': 'B', 'affinity_indoor':'D', 'unit_type': 'striker', 'alt_count': 1,

     'invul': 'no', 'deals_dmg': 'no', 'heals': 'yes', 'heals_team_or_self': 'self', 
     'ex_cost': 4, 'ex_length': 3.17, 'generates_cost': 'no', 'taunts': 'no',
     
     'max_hp': 124633, 'atk': 2764, 'def': 2789, 'dmg_reduction': 0.6259, 'healing': 6899, 'accuracy': 586,
     'evasion': 234, 'crit': 495, 'crit_res': 520, 'crit_dmg': 2.0, 'crit_dmg_res': 0.8, 'stability': 2044,
     'min_dmg': 0.8715, 'stability_rate': 0.2, 'n_range': 350, 's_range': 800, 'cc_power': 100, 'cc_res': 100,
     'recov_boost': 0.5065, 'cost_recovery': 700, 'atk_spd': 1.0, 'mov_spd': 200, 'block_rate_bonus': 0.0,
     'def_piercing': 0, 'mag_count': 8, 'na_cost': 1,
     
     'equip_slot1': 'shoes', 'equip_slot2': 'bag', 'equip_slot3': 'amulet'
     
     },

    # bneru
    {'char': 'bneru', 'atk_type': 'red', 'def_type': 'yellow', 'role': 'tank', 'weapon': 'smg', 'position': 'front',
     'affinity_urban': 'B', 'affinity_outdoor': 'SS', 'affinity_indoor':'D', 'unit_type': 'striker', 'alt_count': 2,

     'invul': 'no', 'deals_dmg': 'yes', 'heals': 'no', 'heals_team_or_self': '?', 
     'ex_cost': 4, 'ex_length': 5.2, 'generates_cost': 'no', 'taunts': 'yes',
     
     'max_hp': 99940, 'atk': 4393, 'def': 1848, 'dmg_reduction': 0.5258, 'healing': 7345, 'accuracy': 109,
     'evasion': 1303, 'crit': 519, 'crit_res': 520, 'crit_dmg': 2.532, 'crit_dmg_res': 0.8, 'stability': 1264,
     'min_dmg': 0.7583, 'stability_rate': 0.2, 'n_range': 450, 's_range': 800, 'cc_power': 100, 'cc_res': 100,
     'recov_boost': 0.0, 'cost_recovery': 700, 'atk_spd': 1.0, 'mov_spd': 200, 'block_rate_bonus': 0.0,
     'def_piercing': 0, 'mag_count': 40, 'na_cost': 10,
     
     'equip_slot1': 'shoes', 'equip_slot2': 'bag', 'equip_slot3': 'amulet'
     
     },

    # atsuko
    {'char': 'atsuko', 'atk_type': 'red', 'def_type': 'blue', 'role': 'tank', 'weapon': 'smg', 'position': 'front',
     'affinity_urban': 'B', 'affinity_outdoor': 'D', 'affinity_indoor':'SS', 'unit_type': 'striker', 'alt_count': 1,

     'invul': 'no', 'deals_dmg': 'no', 'heals': 'yes', 'heals_team_or_self': 'team', 
     'ex_cost': 4, 'ex_length': 3.20, 'generates_cost': 'no', 'taunts': 'no',
     
     'max_hp': 121938, 'atk': 3749, 'def': 151, 'dmg_reduction': 0.0831, 'healing': 13091, 'accuracy': 108,
     'evasion': 2242, 'crit': 216, 'crit_res': 100, 'crit_dmg': 2.0, 'crit_dmg_res': 0.5, 'stability': 1284,
     'min_dmg': 0.7622, 'stability_rate': 0.2, 'n_range': 350, 's_range': 800, 'cc_power': 138, 'cc_res': 100,
     'recov_boost': 0.35, 'cost_recovery': 700, 'atk_spd': 1.0, 'mov_spd': 200, 'block_rate_bonus': 0.0,
     'def_piercing': 0, 'mag_count': 15, 'na_cost': 3,
     
     'equip_slot1': 'shoes', 'equip_slot2': 'badge', 'equip_slot3': 'necklace'
     
     },

    # yuzu
    {'char': 'yuzu', 'atk_type': 'yellow', 'def_type': 'blue', 'role': 'dealer', 'weapon': 'gl', 'position': 'middle',
     'affinity_urban': 'SS', 'affinity_outdoor': 'B', 'affinity_indoor':'D', 'unit_type': 'striker', 'alt_count': 1,

     'invul': 'no', 'deals_dmg': 'yes', 'heals': 'no', 'heals_team_or_self': '?', 
     'ex_cost': 4, 'ex_length': 2.40, 'generates_cost': 'no', 'taunts': 'no',
     
     'max_hp': 54900, 'atk': 10280, 'def': 107, 'dmg_reduction': 0.0603, 'healing': 5792, 'accuracy': 102,
     'evasion': 195, 'crit': 821, 'crit_res': 100, 'crit_dmg': 4.1018, 'crit_dmg_res': 0.5, 'stability': 976,
     'min_dmg': 0.6939, 'stability_rate': 0.2, 'n_range': 650, 's_range': 800, 'cc_power': 100, 'cc_res': 136,
     'recov_boost': 0.0, 'cost_recovery': 700, 'atk_spd': 1.0, 'mov_spd': 200, 'block_rate_bonus': 0.0,
     'def_piercing': 0, 'mag_count': 1, 'na_cost': 1,
     
     'equip_slot1': 'hat', 'equip_slot2': 'hairpin', 'equip_slot3': 'wristwatch'
     
     },

    # shoshino
    {'char': 'shoshino', 'atk_type': 'red', 'def_type': 'blue', 'role': 'support', 'weapon': 'sg', 'position': 'front',
     'affinity_urban': 'SS', 'affinity_outdoor': 'A', 'affinity_indoor':'D', 'unit_type': 'striker', 'alt_count': 2,

     'invul': 'no', 'deals_dmg': 'yes', 'heals': 'yes', 'heals_team_or_self': 'self', 
     'ex_cost': 5, 'ex_length': 2.33, 'generates_cost': 'yes', 'taunts': 'no',
     
     'max_hp': 81604, 'atk': 5983, 'def': 3181, 'dmg_reduction': 0.6562, 'healing': 7295, 'accuracy': 717,
     'evasion': 164, 'crit': 571, 'crit_res': 520, 'crit_dmg': 2.0, 'crit_dmg_res': 0.8, 'stability': 1824,
     'min_dmg': 0.8459, 'stability_rate': 0.2, 'n_range': 450, 's_range': 800, 'cc_power': 100, 'cc_res': 100,
     'recov_boost': 0.0, 'cost_recovery': 700, 'atk_spd': 1.0, 'mov_spd': 200, 'block_rate_bonus': 0.0,
     'def_piercing': 0, 'mag_count': 8, 'na_cost': 1,
     
     'equip_slot1': 'shoes', 'equip_slot2': 'bag', 'equip_slot3': 'amulet'
     
     },



])

# striker_attributes.to_csv('save_figs/striker_attributes.csv')

# %%
# table of all common supporters and attributes

special_attributes = pd.DataFrame([
    # SSHIROKO
    {'char': 'sshiroko', 'atk_type': 'blue', 'def_type': '?', 'role': 'dealer', 'weapon': '?', 'position': 'back',
     'affinity_urban': 'B', 'affinity_outdoor': 'SS', 'affinity_indoor':'D', 'unit_type': 'support', 'alt_count': 2,

     'invul': '?', 'deals_dmg': 'yes', 'heals': 'no', 'heals_one_or_many': '?', 
     'ex_cost': 3, 'ex_length': 4.93, 'generates_cost': 'yes',
     
     'max_hp': 43517, 'atk': 8150, 'def': 2060, 'dmg_reduction': '?', 'healing': 8069, 'accuracy': 660,
     'evasion': 786, 'crit': 734, 'crit_res': 100, 'crit_dmg': 2.46, 'crit_dmg_res': 0.5, 'stability': 1582,
     'min_dmg': 0.8127, 'stability_rate': 0.2, 'n_range': 1000, 'cc_power': 100, 'cc_res': 100,
     'recov_boost': 0.0, 'cost_recovery': 700, 'atk_spd': 1.0, 'mov_spd': '?', 'block_rate_bonus': 0.0, 
     'def_piercing': 0, 'mag_count': '?', 'na_cost': '?',
     
     'equip_slot1': 'hat', 'equip_slot2': 'bag', 'equip_slot3': 'wristwatch'
     
     },
     
    # SAYANE
    {'char': 'sayane', 'atk_type': 'yellow', 'def_type': 'red', 'role': 'ts', 'weapon': '?', 'position': 'back',
     'affinity_urban': 'A', 'affinity_outdoor': 'A', 'affinity_indoor':'B', 'unit_type': 'support', 'alt_count': 1,

     'invul': 'no', 'deals_dmg': 'yes', 'heals': 'no', 'heals_one_or_many': '?', 
     'ex_cost': 4, 'ex_length': 14.53, 'generates_cost': 'no',
     
     'max_hp': 46530, 'atk': 7493, 'def': 1804, 'dmg_reduction': '?', 'healing': 8526, 'accuracy': 1160,
     'evasion': 191, 'crit': 1241, 'crit_res': 100, 'crit_dmg': 2.26, 'crit_dmg_res': 0.5, 'stability': 2194,
     'min_dmg': 0.8869, 'stability_rate': 0.2, 'n_range': 1000, 'cc_power': 100, 'cc_res': 100,
     'recov_boost': 0.0, 'cost_recovery': 700, 'atk_spd': 1.0, 'mov_spd': 200, 'block_rate_bonus': 0.0, 
     'def_piercing': 0, 'mag_count': '?', 'na_cost': '?',
     
     'equip_slot1': 'gloves', 'equip_slot2': 'bag', 'equip_slot3': 'wristwatch'
     
     },

    # SAKI
    {'char': 'saki', 'atk_type': 'yellow', 'def_type': '?', 'role': 'dealer', 'weapon': '?', 'position': 'back',
     'affinity_urban': 'SS', 'affinity_outdoor': 'D', 'affinity_indoor':'B', 'unit_type': 'support', 'alt_count': 1,

     'invul': '?', 'deals_dmg': 'yes', 'heals': 'no', 'heals_one_or_many': '?', 
     'ex_cost': 4, 'ex_length': 7.00, 'generates_cost': 'no',
     
     'max_hp': 41990, 'atk': 8970, 'def': 2132, 'dmg_reduction': '?', 'healing': 11438, 'accuracy': 101,
     'evasion': 197, 'crit': 202, 'crit_res': 100, 'crit_dmg': 2.2, 'crit_dmg_res': 0.5, 'stability': 1582,
     'min_dmg': 0.8127, 'stability_rate': 0.2, 'n_range': 1000, 'cc_power': 186, 'cc_res': 100,
     'recov_boost': 0.0, 'cost_recovery': 700, 'atk_spd': 1.0, 'mov_spd': '?', 'block_rate_bonus': 0.0, 
     'def_piercing': 0, 'mag_count': '?', 'na_cost': '?',
     
     'equip_slot1': 'hat', 'equip_slot2': 'bag', 'equip_slot3': 'necklace'
     
     }, 

    # NAGISA
    {'char': 'nagisa', 'atk_type': 'red', 'def_type': '?', 'role': 'dealer', 'weapon': '?', 'position': 'back',
     'affinity_urban': 'D', 'affinity_outdoor': 'B', 'affinity_indoor':'SS', 'unit_type': 'support', 'alt_count': 1,

     'invul': '?', 'deals_dmg': 'yes', 'heals': 'yes', 'heals_one_or_many': 'one', 
     'ex_cost': 3, 'ex_length': 6.83, 'generates_cost': 'no',
     
     'max_hp': 44099, 'atk': 7734, 'def': 2061, 'dmg_reduction': '?', 'healing': 11519, 'accuracy': 759, 
     'evasion': 977, 'crit': 682, 'crit_res': 100, 'crit_dmg': 2.46, 'crit_dmg_res': 0.5, 'stability': 1132, 
     'min_dmg': 0.731, 'stability_rate': 0.2, 'n_range': 1000, 'cc_power': 100, 'cc_res': 100, 
     'recov_boost': 0.0, 'cost_recovery': 700, 'atk_spd': 1.0, 'mov_spd': '?', 'block_rate_bonus': 0.0, 
     'def_piercing': 0, 'mag_count': '?', 'na_cost': '?',
     
     'equip_slot1': 'hat', 'equip_slot2': 'bag', 'equip_slot3': 'wristwatch'
     
     }, 

    # RIO
    {'char': 'rio', 'atk_type': 'blue', 'def_type': '?', 'role': 'support', 'weapon': '?', 'position': 'back',
     'affinity_urban': 'A', 'affinity_outdoor': 'D', 'affinity_indoor':'SS', 'unit_type': 'support', 'alt_count': 0,

     'invul': '?', 'deals_dmg': 'no', 'heals': 'no', 'heals_one_or_many': '?', 
     'ex_cost': 2, 'ex_length': 6.70, 'generates_cost': 'no',
     
     'max_hp': 67546, 'atk': 5691, 'def': 599, 'dmg_reduction': '?', 'healing': 7564, 'accuracy': 714,
     'evasion': 1151, 'crit': 868, 'crit_res': 100, 'crit_dmg': 2.26, 'crit_dmg_res': 0.5, 'stability': 1201,
     'min_dmg': 0.7457, 'stability_rate': 0.2, 'n_range': 1000, 'cc_power': 100, 'cc_res': 136,
     'recov_boost': 0.0, 'cost_recovery': 700, 'atk_spd': 1.0, 'mov_spd': '?', 'block_rate_bonus': 0.0, 
     'def_piercing': 0, 'mag_count': '?', 'na_cost': '?',
     
     'equip_slot1': 'shoes', 'equip_slot2': 'hairpin', 'equip_slot3': 'wristwatch'
     
     }, 

    # HIBIKI
    {'char': 'hibiki', 'atk_type': 'red', 'def_type': '?', 'role': 'dealer', 'weapon': '?', 'position': 'back',
     'affinity_urban': 'SS', 'affinity_outdoor': 'B', 'affinity_indoor': 'B', 'unit_type': 'support', 'alt_count': 1,

     'invul': '?', 'deals_dmg': 'yes', 'heals': 'no', 'heals_one_or_many': '?', 
     'ex_cost': 4, 'ex_length': 4.00, 'generates_cost': 'no',
     
     'max_hp': 43506, 'atk': 7070, 'def': 437, 'dmg_reduction': '?', 'healing': 7437, 'accuracy': 500, 
     'evasion': 201, 'crit': 831, 'crit_res': 100, 'crit_dmg': 2.46, 'crit_dmg_res': 0.5, 'stability': 1141, 
     'min_dmg': 0.7329, 'stability_rate': 0.2, 'n_range': 1000, 'cc_power': 100, 'cc_res': 136, 
     'recov_boost': 0.0, 'cost_recovery': 700, 'atk_spd': 1.0, 'mov_spd': '?', 'block_rate_bonus': 0.0, 
     'def_piercing': 0, 'mag_count': '?', 'na_cost': '?',
     
     'equip_slot1': 'hat', 'equip_slot2': 'hairpin', 'equip_slot3': 'wristwatch'
     
     }, 

    # MINORI
    {'char': 'minori', 'atk_type': 'red', 'def_type': '?', 'role': 'dealer', 'weapon': '?', 'position': 'back',
     'affinity_urban': 'D', 'affinity_outdoor': 'B', 'affinity_indoor': 'SS', 'unit_type': 'support', 'alt_count': 0,

     'invul': '?', 'deals_dmg': 'yes', 'heals': 'no', 'heals_one_or_many': '?', 
     'ex_cost': 4, 'ex_length': 4.80, 'generates_cost': 'no',
     
     'max_hp': 43678, 'atk': 8106, 'def': 2062, 'dmg_reduction': '?', 'healing': 8023, 'accuracy': 656,
     'evasion': 791, 'crit': 732, 'crit_res': 100, 'crit_dmg': 2.46, 'crit_dmg_res': 0.5, 'stability': 1592,
     'min_dmg': 0.8142, 'stability_rate': 0.2, 'n_range': 1000, 'cc_power': 100, 'cc_res': 100,
     'recov_boost': 0.0, 'cost_recovery': 700, 'atk_spd': 1.0, 'mov_spd': '?', 'block_rate_bonus': 0.0, 
     'def_piercing': 0, 'mag_count': '?', 'na_cost': '?',
     
     'equip_slot1': 'hat', 'equip_slot2': 'bag', 'equip_slot3': 'wristwatch'
     
     }, 

    # IROHA
    {'char': 'iroha', 'atk_type': 'blue', 'def_type': 'yellow', 'role': 'ts', 'weapon': '?', 'position': 'back',
     'affinity_urban': 'D', 'affinity_outdoor': 'B', 'affinity_indoor': 'SS', 'unit_type': 'support', 'alt_count': 0,

     'invul': 'no', 'deals_dmg': 'yes', 'heals': 'no', 'heals_one_or_many': '?', 
     'ex_cost': 6, 'ex_length': 19.17, 'generates_cost': 'no',
     
     'max_hp': 58232, 'atk': 7278, 'def': 110, 'dmg_reduction': '?', 'healing': 7903, 'accuracy': 896,
     'evasion': 650, 'crit': 728, 'crit_res': 100, 'crit_dmg': 2.46, 'crit_dmg_res': 0.5, 'stability': 2309,
     'min_dmg': 0.8978, 'stability_rate': 0.2, 'n_range': 1000, 'cc_power': 100, 'cc_res': 100,
     'recov_boost': 0.35, 'cost_recovery': 700, 'atk_spd': 1.0, 'mov_spd': 200, 'block_rate_bonus': 0.0,
     'def_piercing': 0, 'mag_count': '?', 'na_cost': '?',
     
     'equip_slot1': 'hat', 'equip_slot2': 'badge', 'equip_slot3': 'wristwatch'
     
     }, 

    # NYSERIKA
    {'char': 'nyserika', 'atk_type': 'yellow', 'def_type': '?', 'role': 'support', 'weapon': '?', 'position': 'back',
     'affinity_urban': 'C', 'affinity_outdoor': 'C', 'affinity_indoor': 'SS', 'unit_type': 'support', 'alt_count': 2,

     'invul': '?', 'deals_dmg': 'yes', 'heals': 'no', 'heals_one_or_many': '?', 
     'ex_cost': 3, 'ex_length': 5.77, 'generates_cost': 'no',
     
     'max_hp': 71981, 'atk': 5944, 'def': 1800, 'dmg_reduction': '?', 'healing': 8663, 'accuracy': 763,
     'evasion': 727, 'crit': 698, 'crit_res': 100, 'crit_dmg': 2.26, 'crit_dmg_res': 0.5, 'stability': 1463,
     'min_dmg': 0.794, 'stability_rate': 0.2, 'n_range': 1000, 'cc_power': 100, 'cc_res': 100,
     'recov_boost': 0.0, 'cost_recovery': 700, 'atk_spd': 1.0, 'mov_spd': '?', 'block_rate_bonus': 0.0, 
     'def_piercing': 0, 'mag_count': '?', 'na_cost': '?',
     
     'equip_slot1': 'shoes', 'equip_slot2': 'bag', 'equip_slot3': 'wristwatch'
     
     }, 

    # UTAHA
    {'char': 'utaha', 'atk_type': 'yellow', 'def_type': 'yellow', 'role': 'dealer', 'weapon': '?', 'position': 'back',
     'affinity_urban': 'A', 'affinity_outdoor': 'B', 'affinity_indoor': 'A', 'unit_type': 'support', 'alt_count': 1,

     'invul': 'no', 'deals_dmg': 'yes', 'heals': 'no', 'heals_one_or_many': '?', 
     'ex_cost': 4, 'ex_length': 4.00, 'generates_cost': 'no',
     
     'max_hp': 46592, 'atk': 6449, 'def': 112, 'dmg_reduction': '?', 'healing': 7665, 'accuracy': 318,
     'evasion': 1176, 'crit': 1375, 'crit_res': 100, 'crit_dmg': 2.26, 'crit_dmg_res': 0.5, 'stability': 1638,
     'min_dmg': 0.8209, 'stability_rate': 0.2, 'n_range': 1000, 'cc_power': 100, 'cc_res': 136,
     'recov_boost': 0.0, 'cost_recovery': 700, 'atk_spd': 1.2, 'mov_spd': '?', 'block_rate_bonus': 0.0, 
     'def_piercing': 0, 'mag_count': '?', 'na_cost': '?',
     
     'equip_slot1': 'gloves', 'equip_slot2': 'hairpin', 'equip_slot3': 'wristwatch'
     
     }, 

    # ...
])

# special_attributes.to_csv('save_figs/special_attributes.csv', index=False)

# %%
# affinity

affinity_map = pd.DataFrame([
    {'affinity':'SS', "dmg_mult": 1.3, "block_r": 0.75},
    {'affinity':'S', "dmg_mult": 1.2, "block_r": 0.60},
    {'affinity':'A', "dmg_mult": 1.1, "block_r": 0.45},
    {'affinity':'B', "dmg_mult": 1.0, "block_r": 0.30},
    {'affinity':'C', "dmg_mult": 0.9, "block_r": 0.15},
    {'affinity':'D', "dmg_mult": 0.8, "block_r": 0.00},
])

# affinity_map.to_csv('save_figs/terrain.csv', index=False)

# %%
# color effectiveness

color_map = pd.DataFrame([
    {'attack_color':'red', "red": 2.0, "yellow": 1.0, "blue": 0.5, "purple": 0.5},
    {'attack_color':'yellow', "red": 0.5, "yellow": 2.0, "blue": 1.0, "purple": 1.0},
    {'attack_color':'blue', "red": 1.0, "yellow": 0.5, "blue": 2.0, "purple": 1.0},
    {'attack_color':'purple', "red": 1.0, "yellow": 0.5, "blue": 1.5, "purple": 2.0},
])

# color_map.to_csv('save_figs/color_map.csv', index=False)

# %%
striker_attributes.columns
# Out:
# Index(['char', 'atk_type', 'def_type', 'role', 'weapon', 'position',
#        'affinity_urban', 'affinity_outdoor', 'affinity_indoor', 'unit_type',
#        'alt_count', 'invul', 'deals_dmg', 'heals', 'heals_team_or_self',
#        'ex_cost', 'ex_length', 'generates_cost', 'taunts', 'max_hp', 'atk',
#        'def', 'dmg_reduction', 'healing', 'accuracy', 'evasion', 'crit',
#        'crit_res', 'crit_dmg', 'crit_dmg_res', 'stability', 'min_dmg',
#        'stability_rate', 'n_range', 's_range', 'cc_power', 'cc_res',
#        'recov_boost', 'cost_recovery', 'atk_spd', 'mov_spd',
#        'block_rate_bonus', 'def_piercing', 'mag_count', 'na_cost',
#        'equip_slot1', 'equip_slot2', 'equip_slot3'],
#       dtype='object')

# %%
for i in striker_attributes.columns.to_list():
    print(striker_attributes[i].describe())
# Out:
# count           23
# unique          23
# top       tshiroko
# freq             1
# Name: char, dtype: object
# count         23
# unique         4
# top       yellow
# freq          11
# Name: atk_type, dtype: object
# count         23
# unique         3
# top       yellow
# freq          10
# Name: def_type, dtype: object
# count         23
# unique         3
# top       dealer
# freq          11
# Name: role, dtype: object
# count     23
# unique     6
# top       sg
# freq       7
# Name: weapon, dtype: object
# count        23
# unique        3
# top       front
# freq         14
# Name: position, dtype: object
# count     23
# unique     5
# top        D
# freq       8
# Name: affinity_urban, dtype: object
# count     23
# unique     5
# top        B
# freq       8
# Name: affinity_outdoor, dtype: object
# count     23
# unique     4
# top       SS
# freq       8
# Name: affinity_indoor, dtype: object
# count          23
# unique          1
# top       striker
# ...

# %%
# strikers
continuous = ['ex_length', 'max_hp', 'atk', 'def', 'dmg_reduction', 'healing', 'accuracy', 'evasion', 'crit', 
              'crit_res', 'crit_dmg', 'crit_dmg_res', 'stability', 'min_dmg', 'stability_rate', 'n_range', 's_range',
              'cc_power', 'cc_res', 'recov_boost', 'cost_recovery', 'atk_spd', 'mov_spd', 'block_rate_bonus', 
              'def_piercing', 'mag_count', 'na_cost', 'ex_cost']

ordinal = ['affinity_urban', 'affinity_outdoor', 'affinity_indoor', 'alt_count']
ord_rankings = [['SS','S','A','B','C','D'], ['SS','S','A','B','C','D'], ['SS','S','A','B','C','D'], [2,1,0]] # reverse

categorical = ['char', 'atk_type', 'def_type', 'role', 'weapon', 'position', 'invul', 'deals_dmg', 'heals', 
               'heals_team_or_self', 'generates_cost', 'taunts', 'equip_slot1', 'equip_slot2', 'equip_slot3']

# %%
# all the same: s_range, role, cost_recovery, stability_rate (negligible)

c_striker_attributes = striker_attributes.copy()

c_striker_attributes = c_striker_attributes.drop(columns=['s_range', 'cost_recovery', 'stability_rate', 'unit_type'])

c_striker_attributes.to_csv('apply_figs/f_striker_attributes.csv', index=False)

# %%
for i in special_attributes.columns.to_list():
    print(special_attributes[i].describe())
# Out:
# count           10
# unique          10
# top       sshiroko
# freq             1
# Name: char, dtype: object
# count         10
# unique         3
# top       yellow
# freq           4
# Name: atk_type, dtype: object
# count     10
# unique     3
# top        ?
# freq       7
# Name: def_type, dtype: object
# count          10
# unique          1
# top       support
# freq           10
# Name: role, dtype: object
# count     10
# unique     1
# top        ?
# freq      10
# Name: weapon, dtype: object
# count       10
# unique       1
# top       back
# freq        10
# Name: position, dtype: object
# count     10
# unique     5
# top        A
# freq       3
# Name: affinity_urban, dtype: object
# count     10
# unique     5
# top        B
# freq       5
# Name: affinity_outdoor, dtype: object
# count     10
# unique     4
# top       SS
# freq       5
# Name: affinity_indoor, dtype: object
# count    10.000000
# mean      0.900000
# std       0.737865
# min       0.000000
# ...

# %%
# all the same: s_range, role, cost_recovery, stability_rate (negligible)

c_special_attributes = special_attributes.copy()

c_special_attributes = c_special_attributes.drop(
    columns=['role', 'weapon', 'position', 'dmg_reduction', 'crit_res', 'crit_dmg_res', 'stability_rate', 'n_range', 
             'cost_recovery', 'block_rate_bonus', 'def_piercing', 'mag_count', 'na_cost', 'mov_spd'])

c_special_attributes.to_csv('apply_figs/f_special_attributes.csv', index=False)

# %%
print(c_striker_attributes.columns.to_list())

print(c_special_attributes.columns.to_list())
# Out:
# ['char', 'atk_type', 'def_type', 'weapon', 'position', 'affinity_urban', 'affinity_outdoor', 'affinity_indoor', 'alt_count', 'invul', 'deals_dmg', 'heals', 'heals_team_or_self', 'ex_cost', 'ex_length', 'generates_cost', 'taunts', 'max_hp', 'atk', 'def', 'dmg_reduction', 'healing', 'accuracy', 'evasion', 'crit', 'crit_res', 'crit_dmg', 'crit_dmg_res', 'stability', 'min_dmg', 'n_range', 'cc_power', 'cc_res', 'recov_boost', 'atk_spd', 'mov_spd', 'block_rate_bonus', 'def_piercing', 'mag_count', 'na_cost', 'equip_slot1', 'equip_slot2', 'equip_slot3']
# ['char', 'atk_type', 'def_type', 'affinity_urban', 'affinity_outdoor', 'affinity_indoor', 'unit_type', 'alt_count', 'invul', 'deals_dmg', 'heals', 'heals_one_or_many', 'ex_cost', 'ex_length', 'generates_cost', 'max_hp', 'atk', 'def', 'healing', 'accuracy', 'evasion', 'crit', 'crit_dmg', 'stability', 'min_dmg', 'cc_power', 'cc_res', 'recov_boost', 'atk_spd', 'mov_spd', 'equip_slot1', 'equip_slot2', 'equip_slot3']
